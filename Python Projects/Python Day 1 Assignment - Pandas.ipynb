# %% [markdown]
# **<div align="center">1.	Load the Data:<br>**
# •	Load the CSV file into a Pandas DataFrame.<br>
# •	Data file : GDP (nominal) per Capita

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\nicka\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
student_data = pd.read_csv("student.csv")

gdp = pd.read_csv("GDP_(nominal)_per_Capita.csv")

# %% [markdown]
# **<div align="center">2.	Display the First  and Last 3 Rows:<br>**
# •	Use the head() and tail() functions to display the first and last 3 rows of the DataFrame.

# %%
gdp.head(3)
# Out:
#    Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0           1            Monaco    Europe             0         0
# 1           2     Liechtenstein    Europe             0         0
# 2           3        Luxembourg    Europe        132372      2023
#
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0              234316            2021       234317    2021
# 1              157755            2020       169260    2021
# 2              133590            2021       133745    2021

# %%
gdp.tail(3)
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 220                 480            2021          505    2021
# 221                 369            2021          373    2021
# 222                 222            2021          311    2021

# %% [markdown]
# **<div align="center">3.	Display the dimensions of the data set:<br>**
# •	Use appropriate function to find out number rows and columns in the dataset

# %%
gdp.shape
# Out:
# (223, 9)

# %% [markdown]
# **<div align="center">4.	Display Information about the DataFrame:<br>**
# •	Use the info() function to display concise information about the DataFrame, including the data types and non-null values , record your observations

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          223 non-null    int64
#  1   Country/Territory   223 non-null    object
#  2   UN_Region           223 non-null    object
#  3   IMF_Estimate        223 non-null    int64
#  4   IMF_Year            223 non-null    int64
#  5   WorldBank_Estimate  223 non-null    int64
#  6   WorldBank_Year      223 non-null    int64
#  7   UN_Estimate         223 non-null    int64
#  8   UN_Year             223 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# **<div align="center">5.	Subset Using loc:<br>**
# •	Use the loc indexer to create a subset of the DataFrame. Select specific rows and columns based on labels.

# %%
gdp.loc[5:8,["Country/Territory","IMF_Estimate","UN_Year"]]
# Out:
#   Country/Territory UN_Year
# 5            Norway    2021
# 6       Switzerland    2021
# 7         Singapore    2021
# 8       Isle of Man       0

# %%
# Select a range of rows and consecutive columns using loc
gdp.loc[5:8,"Country/Territory":"UN_Year"]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 5            Norway    Europe        101103      2023               89154
# 6       Switzerland    Europe         98767      2023               91992
# 7         Singapore      Asia         91100      2023               72794
# 8       Isle of Man    Europe             0         0               87158
#
#    WorldBank_Year  UN_Estimate UN_Year
# 5            2021        89242    2021
# 6            2021        93525    2021
# 7            2021        66822    2021
# 8            2019            0       0

# %% [markdown]
# **<div align="center">6.	Subset Using iloc:<br>**
# •	Use the iloc indexer to create another subset of the DataFrame. Select specific rows and columns based on integer positions ( you choose any column you like )

# %%
gdp.iloc[3:8,5:10]  #why dosent it print as a formatted table when single numbers rather than ranges are used?
# Out:
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 3              100172            2021       101109    2021
# 4              114090            2021       112653    2021
# 5               89154            2021        89242    2021
# 6               91992            2021        93525    2021
# 7               72794            2021        66822    2021

# %%
gdp.iloc[3:8,[2,4,6]]
# Out:
#   UN_Region  IMF_Year  WorldBank_Year
# 3    Europe      2023            2021
# 4  Americas         0            2021
# 5    Europe      2023            2021
# 6    Europe      2023            2021
# 7      Asia      2023            2021

# %% [markdown]
# **<div align="center">7.	Conditional Subsetting:<br>**
# •	Use conditional statements to create a subset of the DataFrame.<br>
# •	Subsetting based on specific conditions for numerical columns:<br>
# o	Select rows where the IMF_Estimate is greater than 100.<br>
# o	Select rows where the WorldBank_Estimate is less than 50.<br>
# o	Select rows where the UN_Estimate is between 75 and 150.<br>

# %%
imf100 = gdp[gdp["IMF_Estimate"]>100]
imf100
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 2             3        Luxembourg    Europe        132372      2023
# 3             4           Ireland    Europe        114581      2023
# 5             6            Norway    Europe        101103      2023
# 6             7       Switzerland    Europe         98767      2023
# 7             8         Singapore      Asia         91100      2023
# ..          ...               ...       ...           ...       ...
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 2                133590            2021       133745    2021
# ...

# %%
wb = gdp[gdp["WorldBank_Estimate"]<50]
wb
# Out:
#      Unnamed: 0       Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 30           31  British Virgin Islands  Americas             0         0
# 45           46                  Taiwan      Asia         33907      2023
# 75           76            Cook Islands   Oceania             0         0
# 76           77                Anguilla  Americas             0         0
# 84           85              Montserrat  Americas             0         0
# 195         196                Zanzibar    Africa             0         0
# 211         212             North Korea      Asia             0         0
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 30                    0               0        49444    2021
# 45                    0               0            0       0
# 75                    0               0        19264    2021
# 76                    0               0        19216    2021
# 84                    0               0        16199    2021
# ...

# %%
#Select rows where the UN_Estimate is between 75 and 150.
UN_Estimate_75to150 = gdp[(gdp["UN_Estimate"]>75) & (gdp["UN_Estimate"]<150)]
UN_Estimate_75to150   
#No results - checked in csv file
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country/Territory, UN_Region, IMF_Estimate, IMF_Year, WorldBank_Estimate, WorldBank_Year, UN_Estimate, UN_Year]
# Index: []

# %%
UN_Estimate_75to150.shape
# Out:
# (0, 9)

# %% [markdown]
# **<div align="center">8.	Summary Statistics:<br>**
# •	Generate summary statistics for numerical columns (IMF_Estimate, WorldBank_Estimate, UN_Estimate).

# %%
rounded = gdp[["IMF_Estimate", "WorldBank_Estimate","UN_Estimate"]].describe().round(2)
rounded
# Out:
#        IMF_Estimate  WorldBank_Estimate  UN_Estimate
# count        223.00              223.00        223.0
# mean       15351.63            18927.42      17767.3
# std        22550.90            29103.56      28698.1
# min            0.00                0.00          0.0
# 25%         1406.50             2273.50       2039.0
# 50%         5421.00             6805.00       6396.0
# 75%        19697.00            23715.00      20740.0
# max       132372.00           234316.00     234317.0

# %% [markdown]
# **<div align="center">9.	Analyse based on nonnumeric column:<br>**
# •	Count the number of countries in each UN region.<br>
# •	Create subsets for the following UN regions<br>
# o	Africa – Call this subset GDP_Africa<br>
# o	Europe – Call this subset GDP_Europe<br>
# o	Create summary statistics for the above two regions and compare. Write short paragraphs to describe your findings. <br>
# Feel free to make any assumptions.

# %%
# number of countries in each UN regions - looked up and used https://stackoverflow.com/questions/39607540/count-the-number-of-occurrence-of-values-based-on-another-column
# could also use: GPD_Africa.count() after creating subsets
gdp.groupby("UN_Region").size().sort_values(ascending=False) \
  .reset_index(name="Country/Territory")
# Out:
#   UN_Region  Country/Territory
# 0    Africa                 55
# 1      Asia                 51
# 2  Americas                 48
# 3    Europe                 48
# 4   Oceania                 20
# 5     World                  1

# %%
gdp.UN_Region.value_counts()
# Out:
# UN_Region
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: count, dtype: int64

# %%
GDP_Africa = gdp[gdp["UN_Region"]=="Africa"]
GDP_Europe = gdp[gdp["UN_Region"]=="Europe"]

# %%
GDP_Africa.count()
# Out:
# Unnamed: 0            55
# Country/Territory     55
# UN_Region             55
# IMF_Estimate          55
# IMF_Year              55
# WorldBank_Estimate    55
# WorldBank_Year        55
# UN_Estimate           55
# UN_Year               55
# dtype: int64

# %%
GDP_Europe.count()
# Out:
# Unnamed: 0            48
# Country/Territory     48
# UN_Region             48
# IMF_Estimate          48
# IMF_Year              48
# WorldBank_Estimate    48
# WorldBank_Year        48
# UN_Estimate           48
# UN_Year               48
# dtype: int64

# %%
GDP_Africa.describe().round(2)
# Out:
#        Unnamed: 0  IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# count       55.00         55.00     55.00               55.00           55.00
# mean       178.82       2802.35   1986.22             2470.84         1983.96
# std         35.50       3421.33    272.78             2772.45          272.48
# min         74.00          0.00      0.00                0.00            0.00
# 25%        156.50        833.00   2023.00              762.00         2021.00
# 50%        188.00       1475.00   2023.00             1319.00         2021.00
# 75%        206.50       3696.00   2023.00             3221.50         2021.00
# max        223.00      19536.00   2023.00            14653.00         2021.00
#
#        UN_Estimate
# count        55.00
# mean       2417.93
# std        2521.29
# min         311.00
# 25%         779.00
# 50%        1361.00
# 75%        3320.50
# max       12085.00

# %%
GDP_Europe.describe().round(2)
# Out:
#        Unnamed: 0  IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# count       48.00         48.00     48.00               48.00           48.00
# mean        52.69      34446.75   1812.27            45193.69         2020.62
# std         40.32      31085.66    624.52            43984.13            2.04
# min          1.00          0.00      0.00             4836.00         2007.00
# 25%         19.50      10192.50   2023.00            16978.25         2021.00
# 50%         46.00      27053.00   2023.00            31795.50         2021.00
# 75%         75.75      51774.50   2023.00            58583.25         2021.00
# max        143.00     132372.00   2023.00           234316.00         2021.00
#
#        UN_Estimate
# count        48.00
# mean      40610.79
# std       45233.99
# min           0.00
# 25%       11468.25
# 50%       27400.00
# 75%       51800.25
# max      234317.00

# %% [markdown]
# Africa contains the most countries with 55, followed by Asia with 51, the Americas and Europe both with 48 and Oceania with 20. The data contained IMF, World Bank and UN estimates of GDP across these countries.  IMF data between 2020 - 2023 (with 26 empty records), World bank data from 2007 - 2021 with 7 empty records  while the UN data was taken bin 2021 with 8 empty records. Given the range of time that the data was taken, the World Bank data has validity issues as it wouldnt take into account potential economic growth for data collected at the start of the period.
#
# According to the IMF data, African countries had a mean GDP of 2802.35 compared to 34446.75 in Europe. The World Bank estimated African GDP at 2470.84 and European GDP at 45193.69, while the UN estimated African GDP at 2417.92 compared to 40610.79 in Europe. By all measures a large disparity was found between Europe and African with African countries having much lower GDPs than those in Europe.
#
# By all measurues, the standard deviation for gdp was much greater in Europe (IMF:31085, WB:43984, UN:45234) compared to Africa (IMF:3421, WB:2772, UN:2521). This indicates a larger disparity in gdp in Europe perhaps due to higher GPD in western European countries compared to the east. The lower disparity in Africa indicates a generally low GDP across the continent.
